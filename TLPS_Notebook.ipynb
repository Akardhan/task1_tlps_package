# %% [markdown]
# # TL-PS (Task 1)
# Run this notebook to compute the TL-PS metric and export charts.

# %%
import pandas as pd, numpy as np
from pathlib import Path
print('Ready')

# %%
# %pip -q install pandas pyarrow numpy matplotlib
print('Deps installed')

# %%
# !python metric_tlps.py --transactions transactions.parquet --gnaf gnaf_prop.parquet --state SA --min-dwellings 500 --out tlps_by_suburb.csv --charts 1

# %%
df = pd.read_csv('tlps_by_suburb.csv')
df.head(10)
